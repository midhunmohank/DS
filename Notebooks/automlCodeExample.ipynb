# %%
import h2o
from h2o.automl import H2OAutoML

# %%
# Start the H2O cluster (locally)
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         3 mins 31 secs
# H2O_cluster_timezone:       America/New_York
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.1
# H2O_cluster_version_age:    4 days
# H2O_cluster_name:           H2O_from_python_midhunmohan_datgee
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.933 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.8.9 final
# --------------------------  ----------------------------------

# %%
# Import a sample binary outcome train/test set into H2O
train = h2o.import_file("https://s3.amazonaws.com/erin-data/higgs/higgs_train_10k.csv")
test = h2o.import_file("https://s3.amazonaws.com/erin-data/higgs/higgs_test_5k.csv")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
train.shape
# Out:
# (10000, 29)

# %%
test.shape
# Out:
# (5000, 29)

# %%
# Identify predictors and response
x = train.columns
y = "response"
x.remove(y)

# %%
print(x)
# Out:
# ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28']

# %%
print(y)
# Out:
# response

# %%
# For binary classification, response should be a factor
train[y] = train[y].asfactor()
test[y] = test[y].asfactor()

# %%
# Run AutoML for 20 base models
aml = H2OAutoML(max_models=20, seed=1)
aml.train(x=x, y=y, training_frame=train)
# Out:
# AutoML progress: |
# 19:40:30.959: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_1_AutoML_3_20220417_194030
#
# No model summary for this model
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.09015018855792127
# RMSE: 0.3002502099215274
# LogLoss: 0.32241302813948
# Null degrees of freedom: 9999
# Residual degrees of freedom: 9985
# Null deviance: 13828.11338742424
# Residual deviance: 6448.260562789599
# AIC: 6478.260562789599
# AUC: 0.9743019651406547
# AUCPR: 0.9768372083797083
# Gini: 0.9486039302813094
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4797872016862416:
#                0       1   Error              Rate
# 0      0  4102.0   603.0  0.1282    (603.0/4705.0)
# 1      1   286.0  5009.0   0.054    (286.0/5295.0)
# 2  Total  4388.0  5612.0  0.0889   (889.0/10000.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold        value    idx
# 0                        max f1   0.479787     0.918493  215.0
# 1                        max f2   0.384369     0.949141  249.0
# 2                  max f0point5   0.575551     0.927814  179.0
# 3                  max accuracy   0.496303     0.911300  209.0
# 4                 max precision   0.993703     1.000000    0.0
# 5                    max recall   0.157814     1.000000  343.0
# 6               max specificity   0.993703     1.000000    0.0
# 7              max absolute_mcc   0.479787     0.822586  215.0
# 8    max min_per_class_accuracy   0.530930     0.907120  197.0
# 9   max mean_per_class_accuracy   0.501477     0.909753  207.0
# 10                      max tns   0.993703  4705.000000    0.0
# 11                      max fns   0.993703  5291.000000    0.0
# 12                      max fps   0.002950  4705.000000  399.0
# 13                      max tps   0.157814  5295.000000  343.0
# 14                      max tnr   0.993703     1.000000    0.0
# 15                      max fnr   0.993703     0.999245    0.0
# 16                      max fpr   0.002950     1.000000  399.0
# 17                      max tpr   0.157814     1.000000  343.0
# Gains/Lift Table: Avg response rate: 52.95 %, avg score: 53.23 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1
# 11          0.702721      0.093484                 0.790935  -6.515581
# 12          0.660696      0.081209                 0.872144 -18.791313
# 13          0.618579      0.061756                 0.933900 -38.243626
# 14          0.575942      0.047403                 0.981303 -52.596789
# 15          0.529545      0.018697                 1.000000 -81.303116
#
#     cumulative_gain  kolmogorov_smirnov
# 0         85.080264            0.018083
# 1         83.191690            0.035363
# 2         81.932641            0.052242
# 3         81.303116            0.069121
# 4         79.414542            0.084394
# 5         73.937677            0.157147
# 6         70.097576            0.223478
# 7         65.816808            0.279774
# 8         57.507082            0.366676
# 9         48.772427            0.414643
# 10        39.490085            0.419661
# 11        31.822474            0.405813
# 12        24.591933            0.365874
# 13        16.737488            0.284591
# 14         9.033680            0.172802
# 15         0.000000            0.000000
# Cross-Validation Metrics Summary:
#                                     mean          sd   cv_1_valid  \
# 0                  accuracy     0.701665    0.008066     0.699902
# 1                       auc     0.790530    0.007520     0.797346
# 2                       err     0.298335    0.008066     0.300098
# 3                 err_count   596.600000   25.135632   614.000000
# 4                  f0point5     0.700826    0.006945     0.699504
# 5                        f1     0.753761    0.010724     0.762751
# 6                        f2     0.815588    0.021428     0.838573
# 7            lift_top_group     1.852598    0.064909     1.861692
# 8                   logloss     0.548889    0.008544     0.541193
# 9       max_per_class_error     0.481723    0.051976     0.530095
# 10                      mcc     0.410561    0.016281     0.412230
# 11  mean_per_class_accuracy     0.690613    0.012402     0.683997
# 12     mean_per_class_error     0.309387    0.012402     0.316003
# 13                      mse     0.186122    0.003616     0.182976
# 14            null_deviance  2766.241200  103.854140  2825.814700
# 15                   pr_auc     0.808720    0.010526     0.817624
# 16                precision     0.669556    0.008862     0.662861
# 17                       r2     0.252465    0.013647     0.264033
# 18                   recall     0.862950    0.031410     0.898089
# 19        residual_deviance  2195.778600   93.139940  2214.561000
#
#      cv_2_valid   cv_3_valid   cv_4_valid   cv_5_valid
# 0      0.715769     0.698242     0.695371     0.699039
# 1      0.797852     0.780025     0.786570     0.790857
# 2      0.284231     0.301758     0.304629     0.300961
# 3    575.000000   618.000000   612.000000   564.000000
# 4      0.711079     0.692742     0.697211     0.703593
# 5      0.755215     0.735445     0.755396     0.760000
# 6      0.805192     0.783759     0.824176     0.826240
# 7      1.829693     1.954198     1.776540     1.840864
# 8      0.542363     0.561195     0.554143     0.545552
# 9      0.421650     0.429000     0.515021     0.512850
# 10     0.438035     0.404214     0.398024     0.400303
# 11     0.710353     0.695328     0.681208     0.682180
# 12     0.289647     0.304672     0.318792     0.317820
# 13     0.183230     0.191721     0.187482     0.185204
# 14  2802.097400  2842.113800  2775.139200  2586.040500
# 15     0.808662     0.794079     0.803470     0.819764
# 16     0.684414     0.666925     0.663158     0.670420
# 17     0.265846     0.232694     0.246146     0.253608
# 18     0.842355     0.819657     0.877437     0.877210
# 19  2194.400400  2298.653800  2226.546100  2044.730500
# See the whole table with table.as_data_frame()

# %%
# View the AutoML Leaderboard
lb = aml.leaderboard
lb.head(rows=lb.nrows)  # Print all rows instead of default (10 rows)

# %%
aml.leader
